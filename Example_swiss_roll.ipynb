# %% [markdown]
# This notebook shows an example of NRPCA algorithm applied to synthetic swissroll dataset

# %%
# %run main.py -niter 150 -num_runs 2
# Out:
# new
# Start round 0 of NRPCA ...
# Start solving minimization problem...
# Iter 0
# Objective value: [87583.30182855]
# Iter 1
# Objective value: [87391.93271883]
# Iter 2
# Objective value: [87157.75457987]
# Iter 3
# Objective value: [86889.26594404]
# Iter 4
# Objective value: [86595.12891058]
# Iter 5
# Objective value: [86284.14416087]
# Iter 6
# Objective value: [85965.01701772]
# Iter 7
# Objective value: [85646.01460466]
# Iter 8
# Objective value: [85334.56468812]
# Iter 9
# Objective value: [85036.84753044]
# Iter 10
# Objective value: [84757.56597734]
# Iter 11
# Objective value: [84499.88560977]
# Iter 12
# Objective value: [84265.35485412]
# Iter 13
# Objective value: [84054.0043463]
# Iter 14
# Objective value: [83864.59009776]
# Iter 15
# Objective value: [83695.04487268]
# Iter 16
# Objective value: [83542.97727239]
# Iter 17
# Objective value: [83406.04516992]
# Iter 18
# Objective value: [83282.00225647]
# Iter 19
# Objective value: [83168.74144863]
# Iter 20
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(25,15))
plt.subplot(231)
plt.scatter(X[:,0],X[:,1],c=color,s=1)
plt.title(f'Noisy data: $\widetilde X$',fontsize=20)
plt.subplot(232)
plt.scatter(L[0][:,0],L[0][:,1],c=color,s=1)
plt.title(f'$\widetilde X-\hat S$',fontsize=20)
plt.subplot(233)
plt.scatter(L[1][:,0],L[1][:,1],c=color,s=1)
plt.title(f'$\widetilde X-\hat S$ with one neighbor update',fontsize=20)
plt.subplot(234)
plt.scatter(X_hat[:,0],X_hat[:,1],c=color,s=1)
plt.title(f'$\hat X$',fontsize=20)
plt.subplot(235)
plt.scatter(clean_X[:,0],clean_X[:,1],c=color,s=1)
plt.title('Clean data: $X$',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Clean data: $X$')
