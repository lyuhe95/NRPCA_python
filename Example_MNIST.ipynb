# %% [markdown]
# This notebook shows an example of NRPCA algorithm applied to MNIST dataset
#
# The dataset we select includes 2000 samples of handwritten digital numbers 4 and 9

# %%
# %run main.py -data MNIST -N 2000 -niter 150 -num_runs 2
# Out:
# Start round 0 of NRPCA ...
# Start solving minimization problem...
# Iter 0
# Objective value: [117269.72768643]
# Iter 1
# Objective value: [116467.48287131]
# Iter 2
# Objective value: [115459.47287561]
# Iter 3
# Objective value: [114265.89473391]
# Iter 4
# Objective value: [112907.71260908]
# Iter 5
# Objective value: [111407.91504606]
# Iter 6
# Objective value: [109791.98169883]
# Iter 7
# Objective value: [108087.77717918]
# Iter 8
# Objective value: [106324.71381154]
# Iter 9
# Objective value: [104532.3670633]
# Iter 10
# Objective value: [102739.12039659]
# Iter 11
# Objective value: [100970.4124588]
# Iter 12
# Objective value: [99247.15893807]
# Iter 13
# Objective value: [97585.78452388]
# Iter 14
# Objective value: [95997.38059431]
# Iter 15
# Objective value: [94489.25829802]
# Iter 16
# Objective value: [93065.72615668]
# Iter 17
# Objective value: [91726.7631406]
# Iter 18
# Objective value: [90471.13475102]
# Iter 19
# Objective value: [89297.83346242]
# Iter 20
# Objective value: [88204.59747447]
# Iter 21
# Objective value: [87183.51778873]
# Iter 22
# Objective value: [86232.69106939]
# Iter 23
# Objective value: [85347.2119931]
# Iter 24
# Objective value: [84524.40303997]
# Iter 25
# Objective value: [83760.05798869]
# Iter 26
# Objective value: [83049.28851654]
# Iter 27
# Objective value: [82390.35098141]
# Iter 28
# Objective value: [81777.98312739]
# Iter 29
# Objective value: [81208.037489]
# Iter 30
# Objective value: [80678.1413712]
# Iter 31
# Objective value: [80185.31584282]
# Iter 32
# Objective value: [79723.56347005]
# Iter 33
# Objective value: [79292.56681905]
# Iter 34
# Objective value: [78890.45680795]
# Iter 35
# Objective value: [78512.71357057]
# Iter 36
# Objective value: [78161.43858067]
# Iter 37
# Objective value: [77834.67681188]
# Iter 38
# Objective value: [77526.2464208]
# Iter 39
# Objective value: [77240.9466983]
# Iter 40
# Objective value: [76975.33218264]
# Iter 41
# Objective value: [76722.82636633]
# Iter 42
# Objective value: [76492.5956378]
# Iter 43
# Objective value: [76278.05070631]
# Iter 44
# Objective value: [76072.27627165]
# Iter 45
# Objective value: [75886.43841882]
# Iter 46
# Objective value: [75710.94346094]
# Iter 47
# Objective value: [75542.35483576]
# Iter 48
# Objective value: [75391.86718743]
# Iter 49
# Objective value: [75249.44365232]
# Iter 50
# Objective value: [75115.05958917]
# Iter 51
# Objective value: [74996.05749244]
# Iter 52
# Objective value: [74880.95461455]
# Iter 53
# Objective value: [74770.92050213]
# Iter 54
# Objective value: [74672.51666972]
# Iter 55
# Objective value: [74578.05852882]
# Iter 56
# Objective value: [74485.20560664]
# Iter 57
# Objective value: [74403.48626418]
# Iter 58
# Objective value: [74325.91814166]
# Iter 59
# Objective value: [74251.70633757]
# Iter 60
# Objective value: [74183.33264073]
# Iter 61
# Objective value: [74120.62273113]
# Iter 62
# Objective value: [74059.90981355]
# Iter 63
# Objective value: [74003.45189767]
# Iter 64
# Objective value: [73954.1460899]
# Iter 65
# Objective value: [73906.08711238]
# Iter 66
# Objective value: [73860.3658795]
# Iter 67
# Objective value: [73821.28816089]
# Iter 68
# Objective value: [73781.0064247]
# Iter 69
# Objective value: [73742.62563065]
# Iter 70
# Objective value: [73711.21021499]
# Iter 71
# Objective value: [73676.158015]
# Iter 72
# Objective value: [73643.77524832]
# Iter 73
# Objective value: [73620.22438113]
# Iter 74
# Objective value: [73588.83659875]
# Iter 75
# Objective value: [73564.08413232]
# Iter 76
# Objective value: [73546.42407759]
# Iter 77
# Objective value: [73519.07507048]
# Iter 78
# Objective value: [73497.48218904]
# Iter 79
# Objective value: [73482.43890491]
# Iter 80
# Objective value: [73458.18791483]
# Iter 81
# Objective value: [73439.79935067]
# Iter 82
# Objective value: [73429.586868]
# Iter 83
# Objective value: [73408.84643659]
# Iter 84
# Objective value: [73393.46369248]
# Iter 85
# Objective value: [73386.28602058]
# Iter 86
# Objective value: [73367.65440247]
# Iter 87
# Objective value: [73356.09734355]
# Iter 88
# Objective value: [73350.36833932]
# Iter 89
# Objective value: [73332.25803683]
# Iter 90
# Objective value: [73321.91766507]
# Iter 91
# Objective value: [73317.80887772]
# Iter 92
# Objective value: [73301.98618338]
# Iter 93
# Objective value: [73293.01656463]
# Iter 94
# Objective value: [73290.06776849]
# Iter 95
# Objective value: [73276.0970391]
# Iter 96
# Objective value: [73266.93802005]
# Iter 97
# Objective value: [73265.84003118]
# Iter 98
# Objective value: [73252.50556801]
# Iter 99
# Objective value: [73245.47398636]
# Iter 100
# Objective value: [73244.93699246]
# Iter 101
# Objective value: [73232.46127493]
# Iter 102
# Objective value: [73225.3061021]
# Iter 103
# Objective value: [73225.98961117]
# Iter 104
# Objective value: [73213.32941041]
# Iter 105
# Objective value: [73207.80264695]
# Iter 106
# Objective value: [73208.71750974]
# Iter 107
# Objective value: [73198.28277036]
# Iter 108
# Objective value: [73193.68832708]
# Iter 109
# Objective value: [73193.15551548]
# Iter 110
# Objective value: [73183.79841748]
# Iter 111
# Objective value: [73180.82479508]
# Iter 112
# Objective value: [73179.6963957]
# Iter 113
# Objective value: [73173.52441859]
# Iter 114
# Objective value: [73168.3194684]
# Iter 115
# Objective value: [73167.40507288]
# Iter 116
# Objective value: [73160.37890723]
# Iter 117
# Objective value: [73156.944595]
# Iter 118
# Objective value: [73156.78438613]
# Iter 119
# Objective value: [73150.9493363]
# Iter 120
# Objective value: [73146.59790542]
# Iter 121
# Objective value: [73146.88260528]
# Iter 122
# Objective value: [73140.94018995]
# Iter 123
# Objective value: [73137.62781216]
# Iter 124
# Objective value: [73140.27139791]
# Iter 125
# Objective value: [73134.85464516]
# Iter 126
# Objective value: [73130.57706486]
# Iter 127
# Objective value: [73133.88267557]
# Iter 128
# Objective value: [73128.07173218]
# Iter 129
# Objective value: [73125.35589244]
# Iter 130
# Objective value: [73130.44556437]
# Iter 131
# Objective value: [73123.92020908]
# Iter 132
# Objective value: [73120.10291956]
# Iter 133
# Objective value: [73127.09326517]
# Iter 134
# Objective value: [73118.55119579]
# Iter 135
# Objective value: [73116.28703913]
# Iter 136
# Objective value: [73124.99655195]
# Iter 137
# Objective value: [73115.90180578]
# Iter 138
# Objective value: [73111.80903104]
# Iter 139
# Objective value: [73121.07477135]
# Iter 140
# Objective value: [73111.03982514]
# Iter 141
# Objective value: [73108.36488001]
# Iter 142
# Objective value: [73118.50590686]
# Iter 143
# Objective value: [73108.71680282]
# Iter 144
# Objective value: [73104.66764381]
# Iter 145
# Objective value: [73114.80132401]
# Iter 146
# Objective value: [73104.60468465]
# Iter 147
# Objective value: [73101.45828414]
# Iter 148
# Objective value: [73112.871655]
# Iter 149
# Objective value: [73102.7314532]
# Start round 1 of NRPCA ...
# Start solving minimization problem...
# Iter 0
# Objective value: [126398.17562954]
# Iter 1
# Objective value: [125464.38493046]
# Iter 2
# Objective value: [124276.4876543]
# Iter 3
# Objective value: [122847.71907877]
# Iter 4
# Objective value: [121190.26141372]
# Iter 5
# Objective value: [119316.77419003]
# Iter 6
# Objective value: [117241.25678146]
# Iter 7
# Objective value: [114979.75490775]
# Iter 8
# Objective value: [112551.09680628]
# Iter 9
# Objective value: [109977.70177094]
# Iter 10
# Objective value: [107286.47008583]
# Iter 11
# Objective value: [104510.01975277]
# Iter 12
# Objective value: [101682.97039134]
# Iter 13
# Objective value: [98844.2260043]
# Iter 14
# Objective value: [96032.93522586]
# Iter 15
# Objective value: [93283.84754375]
# Iter 16
# Objective value: [90628.50582182]
# Iter 17
# Objective value: [88101.26208169]
# Iter 18
# Objective value: [85716.84148225]
# Iter 19
# Objective value: [83492.01287676]
# Iter 20
# Objective value: [81434.88435734]
# Iter 21
# Objective value: [79538.70201572]
# Iter 22
# Objective value: [77803.92129118]
# Iter 23
# Objective value: [76232.55254742]
# Iter 24
# Objective value: [74819.51596352]
# Iter 25
# Objective value: [73550.98839804]
# Iter 26
# Objective value: [72410.0330156]
# Iter 27
# Objective value: [71391.68078505]
# Iter 28
# Objective value: [70485.48582532]
# Iter 29
# Objective value: [69687.18124264]
# Iter 30
# Objective value: [68978.33794691]
# Iter 31
# Objective value: [68349.78907923]
# Iter 32
# Objective value: [67795.5500229]
# Iter 33
# Objective value: [67315.12727638]
# Iter 34
# Objective value: [66882.61917866]
# Iter 35
# Objective value: [66504.08332518]
# Iter 36
# Objective value: [66168.47070392]
# Iter 37
# Objective value: [65870.56545397]
# Iter 38
# Objective value: [65605.19607782]
# Iter 39
# Objective value: [65364.28820996]
# Iter 40
# Objective value: [65147.31173998]
# Iter 41
# Objective value: [64950.55211658]
# Iter 42
# Objective value: [64781.85670457]
# Iter 43
# Objective value: [64626.48414465]
# Iter 44
# Objective value: [64487.62120507]
# Iter 45
# Objective value: [64373.0803992]
# Iter 46
# Objective value: [64260.28942204]
# Iter 47
# Objective value: [64157.73275293]
# Iter 48
# Objective value: [64076.04533421]
# Iter 49
# Objective value: [63991.8878581]
# Iter 50
# Objective value: [63918.76140224]
# Iter 51
# Objective value: [63859.36823166]
# Iter 52
# Objective value: [63794.46292607]
# Iter 53
# Objective value: [63734.86619504]
# Iter 54
# Objective value: [63691.78859697]
# Iter 55
# Objective value: [63644.91871893]
# Iter 56
# Objective value: [63602.19458426]
# Iter 57
# Objective value: [63563.62597814]
# Iter 58
# Objective value: [63529.25119176]
# Iter 59
# Objective value: [63501.75047809]
# Iter 60
# Objective value: [63472.31932445]
# Iter 61
# Objective value: [63440.61845052]
# Iter 62
# Objective value: [63421.05370284]
# Iter 63
# Objective value: [63401.07634466]
# Iter 64
# Objective value: [63375.34228214]
# Iter 65
# Objective value: [63360.42371371]
# Iter 66
# Objective value: [63346.34303577]
# Iter 67
# Objective value: [63325.28633796]
# Iter 68
# Objective value: [63315.48758956]
# Iter 69
# Objective value: [63300.5145739]
# Iter 70
# Objective value: [63283.6501085]
# Iter 71
# Objective value: [63275.06083446]
# Iter 72
# Objective value: [63266.47336629]
# Iter 73
# Objective value: [63250.92089573]
# Iter 74
# Objective value: [63249.08392827]
# Iter 75
# Objective value: [63238.39725523]
# Iter 76
# Objective value: [63224.94389569]
# Iter 77
# Objective value: [63222.85098282]
# Iter 78
# Objective value: [63216.32304394]
# Iter 79
# Objective value: [63203.87778313]
# Iter 80
# Objective value: [63206.74498472]
# Iter 81
# Objective value: [63196.24755688]
# Iter 82
# Objective value: [63187.58815402]
# Iter 83
# Objective value: [63189.36300192]
# Iter 84
# Objective value: [63180.90932506]
# Iter 85
# Objective value: [63176.77200793]
# Iter 86
# Objective value: [63178.81630521]
# Iter 87
# Objective value: [63169.40229252]
# Iter 88
# Objective value: [63167.11121093]
# Iter 89
# Objective value: [63167.36629259]
# Iter 90
# Objective value: [63157.50228784]
# Iter 91
# Objective value: [63160.4343236]
# Iter 92
# Objective value: [63162.64512414]
# Iter 93
# Objective value: [63154.13988083]
# Iter 94
# Objective value: [63154.53062144]
# Iter 95
# Objective value: [63154.94161791]
# Iter 96
# Objective value: [63146.1864297]
# Iter 97
# Objective value: [63146.2485889]
# Iter 98
# Objective value: [63147.97279782]
# Iter 99
# Objective value: [63140.19300012]
# Iter 100
# Objective value: [63139.03245425]
# Iter 101
# Objective value: [63141.62127788]
# Iter 102
# Objective value: [63135.70006075]
# Iter 103
# Objective value: [63133.3427911]
# Iter 104
# Objective value: [63136.85764878]
# Iter 105
# Objective value: [63127.26746793]
# Iter 106
# Objective value: [63130.47217949]
# Iter 107
# Objective value: [63133.43748925]
# Iter 108
# Objective value: [63125.20476076]
# Iter 109
# Objective value: [63125.49710924]
# Iter 110
# Objective value: [63126.05065397]
# Iter 111
# Objective value: [63122.77484126]
# Iter 112
# Objective value: [63125.65257792]
# Iter 113
# Objective value: [63124.26305938]
# Iter 114
# Objective value: [63116.10960869]
# Iter 115
# Objective value: [63122.49464232]
# Iter 116
# Objective value: [63120.68742347]
# Iter 117
# Objective value: [63117.39258366]
# Iter 118
# Objective value: [63119.33261635]
# Iter 119
# Objective value: [63119.90641991]
# Iter 120
# Objective value: [63112.57373188]
# Iter 121
# Objective value: [63114.94493818]
# Iter 122
# Objective value: [63116.69496757]
# Iter 123
# Objective value: [63108.57802326]
# Iter 124
# Objective value: [63113.24860831]
# Iter 125
# Objective value: [63117.51725801]
# Iter 126
# Objective value: [63107.165503]
# Iter 127
# Objective value: [63110.19296563]
# Iter 128
# Objective value: [63112.97217762]
# Iter 129
# Objective value: [63103.12604467]
# Iter 130
# Objective value: [63111.25568589]
# Iter 131
# Objective value: [63112.23928448]
# Iter 132
# Objective value: [63102.95555418]
# Iter 133
# Objective value: [63109.43798774]
# Iter 134
# Objective value: [63109.89162431]
# Iter 135
# Objective value: [63103.20000302]
# Iter 136
# Objective value: [63105.68890413]
# Iter 137
# Objective value: [63108.86930386]
# Iter 138
# Objective value: [63103.24321016]
# Iter 139
# Objective value: [63099.54182141]
# Iter 140
# Objective value: [63105.14259935]
# Iter 141
# Objective value: [63100.10258019]
# Iter 142
# Objective value: [63099.19168431]
# Iter 143
# Objective value: [63104.53246019]
# Iter 144
# Objective value: [63101.95246645]
# Iter 145
# Objective value: [63097.6250031]
# Iter 146
# Objective value: [63102.1614981]
# Iter 147
# Objective value: [63102.07192014]
# Iter 148
# Objective value: [63097.11662194]
# Iter 149
# Objective value: [63104.13385514]

# %%
from random import choices
import numpy as np
import matplotlib.pyplot as plt
N = 2000
indices = choices(list(np.arange(N//2)),k=24) + choices(list(np.arange(N//2,N)),k=24) 
for i in range(6):
    for j in range(8):
        tmp_ori = np.concatenate((tmp_ori,X[indices[8*i+j]].reshape(28,28)),axis=1) \
        if j else X[indices[8*i+j]].reshape(28,28)
        tmp_rec1 = np.concatenate((tmp_rec1,L[0][indices[8*i+j]].reshape(28,28)),axis=1) \
        if j else L[0][indices[8*i+j]].reshape(28,28)
        tmp_rec2 = np.concatenate((tmp_rec2,L[1][indices[8*i+j]].reshape(28,28)),axis=1) \
        if j else L[1][indices[8*i+j]].reshape(28,28)
    images_ori = np.concatenate((images_ori,tmp_ori),axis=0) if i else tmp_ori
    images_rec1 = np.concatenate((images_rec1,tmp_rec1),axis=0) if i else tmp_rec1
    images_rec2 = np.concatenate((images_rec2,tmp_rec2),axis=0) if i else tmp_rec2

plt.figure(figsize=(20,10))
plt.subplot(131)
plt.imshow(images_ori,cmap='gray')
plt.title('Original images')
plt.subplot(132)
plt.imshow(images_rec1,cmap='gray')
plt.title('Denoised images with T=1')
plt.subplot(133)
plt.imshow(images_rec2,cmap='gray')
plt.title('Denoised images with T=2')
# Out:
# Text(0.5, 1.0, 'Denoised images with T=2')
